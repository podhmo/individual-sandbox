# %%
import numpy as np
np.random.randn(8)
# Out:
# array([ 1.34258763,  0.50376178,  1.07689096, -0.28636492,  0.55059163,
#         1.49853272, -2.20599754,  1.94906497])

# %%
import numpy as np
import pandas as pd

pd.Series(np.random.randn(8)).describe()
# Out:
# count    8.000000
# mean     0.075788
# std      0.860559
# min     -1.359061
# 25%     -0.422808
# 50%      0.433942
# 75%      0.613773
# max      0.964740
# dtype: float64

# %%
# %matplotlib inline
import numpy as np
import pandas as pd

pd.Series(np.random.randn(8)).plot()

# %%
# %matplotlib inline
import numpy as np
import pandas as pd

pd.Series(np.random.rand(1000)).hist()

# %%
# %matplotlib inline
import numpy as np
import pandas as pd

pd.Series(np.random.randn(1000)).hist()

# %%
# %matplotlib inline
import numpy as np
import pandas as pd

df = pd.DataFrame(np.random.rand(50, 2), columns=['x', 'y'])
df.plot.scatter(x='x', y='y');

# %%
N = 300
m = np.zeros((2,N))
m[0] = np.random.rand(N)
m[1] = np.random.randn(N)

df = pd.DataFrame(m.T, columns=["x", "y"])
df.plot(kind="scatter",x="x",y="y")

# %%
N = 300
df = pd.DataFrame(dict(a=np.random.rand(100), b=np.random.randn(100)))
df.hist()
# Out:
# array([[<matplotlib.axes._subplots.AxesSubplot object at 0x10c250ba8>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x10c71deb8>]], dtype=object)
